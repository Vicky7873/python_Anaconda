# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# big data
a=np.random.uniform(0,15,1000)

# %%
plt.hist(a,200)
plt.show()

# %%
x = np.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()

# %%
z=np.random.normal(1,15,100000)
plt.hist(z,200)
plt.show()

# %%
x=np.random.randint(1,10,100)
y=np.random.randint(0,10,100)
plt.scatter(x,y)
plt.show()

# %%
x=np.random.normal(1,5,1000)
y=np.random.normal(10,1,1000)
plt.scatter(x,y)
plt.show()
