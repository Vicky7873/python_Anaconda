# %%
# ip="d t "
# op="data"
s="d t "

# %%
s=s.replace(" ","a")

# %%
s
# Out:
# 'data'

# %%
from keras.models import Sequential

# %%
pip install tensorflow
# Out:
# ...
#    ---------------------------------------- 0.0/377.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/377.0 MB 9.6 MB/s eta 0:00:40
#    ---------------------------------------- 0.6/377.0 MB 6.1 MB/s eta 0:01:02
#    ---------------------------------------- 0.9/377.0 MB 6.2 MB/s eta 0:01:01
#    ---------------------------------------- 1.1/377.0 MB 6.1 MB/s eta 0:01:02
#    ---------------------------------------- 1.5/377.0 MB 6.2 MB/s eta 0:01:01
#    ---------------------------------------- 1.8/377.0 MB 5.9 MB/s eta 0:01:04
#    ---------------------------------------- 2.1/377.0 MB 6.1 MB/s eta 0:01:02
#    ---------------------------------------- 2.4/377.0 MB 6.2 MB/s eta 0:01:01
#    ---------------------------------------- 2.6/377.0 MB 6.0 MB/s eta 0:01:03
#    ---------------------------------------- 2.9/377.0 MB 6.0 MB/s eta 0:01:03
#    ---------------------------------------- 3.3/377.0 MB 6.0 MB/s eta 0:01:03
# ...

# %%
pip install keras
# Out:
# ...
#      ---------------------------------------- 0.0/46.2 kB ? eta -:--:--
#      ----------------------------------- ---- 41.0/46.2 kB ? eta -:--:--
#      ----------------------------------- ---- 41.0/46.2 kB ? eta -:--:--
#      ----------------------------------- ---- 41.0/46.2 kB ? eta -:--:--
#      ----------------------------------- ---- 41.0/46.2 kB ? eta -:--:--
#      ----------------------------------- ---- 41.0/46.2 kB ? eta -:--:--
#      ----------------------------------- ---- 41.0/46.2 kB ? eta -:--:--
#      ----------------------------------- ---- 41.0/46.2 kB ? eta -:--:--
#      --------------------------------------- 46.2/46.2 kB 85.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB 5.2 MB/s eta 0:00:01
#    -------------- ------------------------- 0.4/1.1 MB 5.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.7/1.1 MB 5.2 MB/s eta 0:00:01
# ...
