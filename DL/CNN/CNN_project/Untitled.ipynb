# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Conv2D,MaxPooling2D,Flatten

# %%
import numpy as np
import pandas as pd
import random

# %%
path=r'C:\Users\User\Downloads\CNN-for-image-Classification-master\CNN-for-image-Classification-master\dataset\training_set'
path_test=r'C:\Users\User\Downloads\CNN-for-image-Classification-master\CNN-for-image-Classification-master\dataset\test_set'

# %% [markdown]
# # For the data Augumentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_aug=ImageDataGenerator(rescale=1./255,rotation_range=0.5,horizontal_flip=True,vertical_flip=True)

# %%
train_data=train_aug.flow_from_directory(path,batch_size=32,target_size=(100,100),class_mode='binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %%
# after reshape
train_data[0]
# Out:
# (array([[[[0.6731072 , 0.7554602 , 0.82997   ],
#           [0.67305654, 0.76876   , 0.8379296 ],
#           [0.686356  , 0.7883168 , 0.85498345],
#           ...,
#           [0.6955206 , 0.6669539 , 0.6236731 ],
#           [0.7007014 , 0.66652334, 0.6247889 ],
#           [0.7099471 , 0.6627451 , 0.62619156]],
#
#          [[0.6784314 , 0.7607844 , 0.8352942 ],
#           [0.6784314 , 0.7742618 , 0.84338063],
#           [0.6919084 , 0.7938692 , 0.86053586],
#           ...,
#           [0.68095857, 0.65707886, 0.6172989 ],
#           [0.70117927, 0.6704435 , 0.6314552 ],
#           [0.69424576, 0.6532975 , 0.61760956]],
#
#          [[0.6784314 , 0.7607844 , 0.8352942 ],
#           [0.6784314 , 0.77438855, 0.84345675],
#           [0.6920352 , 0.793996  , 0.86066264],
#           ...,
#           [0.67471504, 0.6582221 , 0.6282867 ],
#           [0.689417  , 0.6684556 , 0.6396611 ],
#           [0.66975427, 0.63688636, 0.6114494 ]],
#
#          ...,
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
type(train_data)
# Out:
# keras.src.legacy.preprocessing.image.DirectoryIterator

# %%
# image_array = np.array(train_data)

# %%
test_data=ImageDataGenerator(rescale=1./255)

# %% [markdown]
# # build the model

# %%
model=Sequential()

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation = 'relu', input_shape = (100, 100, 3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(32, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(64, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_data,validation_data=test_data,epochs=10,batch_size = 250)
# Out:
# Epoch 1/10
# C:\Users\User\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 794ms/step - accuracy: 0.5458 - loss: 0.6848
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 model.fit(train_data,validation_data=test_data,epochs=10,batch_size = 250)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
# ...
