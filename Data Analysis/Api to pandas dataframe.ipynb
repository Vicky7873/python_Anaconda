# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import requests
# to fetch the data from api use this library

# %%
response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1').json()

# %%
# create a dictionary and send it to a dataframe
d={'name':['bhiki','pallai'],'age':[25,26]}
pd.DataFrame(d)
# Out:
#      name  age
# 0   bhiki   25
# 1  pallai   26

# %%
# fetch the data using for loop
popularity=[]
vote_count=[]
original_language=[]
title=[]
vote_average=[]
overview=[]
release_date=[]

for i in response['results']:
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    title.append(i['title'])
    vote_average.append(i['vote_average'])
    release_date.append(i['release_date'])
    overview.append(i['overview'])

    
d={'title':title,'overview':overview,'original_language':original_language,'release_date':release_date,'popularity':popularity,'vote_count':vote_count,'vote_average':vote_average}

df=pd.DataFrame(d)
df
# Out:
#                                           title  \
# 0                                    Black Adam
# 1                                The Woman King
# 2                R.I.P.D. 2: Rise of the Damned
# 3                                           Hex
# 4                                         Polar
# 5                                       One Way
# 6                Black Panther: Wakanda Forever
# 7                                 Paradise City
# 8                   The Minute You Wake Up Dead
# 9                                    Cop Secret
# 10  The Guardians of the Galaxy Holiday Special
# 11                                     Blowback
# 12                                Lost Bullet 2
# 13                          Corrective Measures
# 14                                  Lesson Plan
# 15                                        Smile
# 16                                 Disenchanted
# 17                                        Troll
# 18                      Sniper: The White Raven
# 19                        Lyle, Lyle, Crocodile
#
#                                              overview original_language  \
# 0   Nearly 5,000 years after he was bestowed with ...                en
# 1   The story of the Agojie, the all-female unit o...                en
# 2   When Sheriff Roy Pulsipher finds himself in th...                en
# 3   Following a mysterious disappearance on a jump...                en
# 4   MG, a policewoman who has been expelled from t...                es
# 5   On the run with a bag full of cash after a rob...                en
# 6   Queen Ramonda, Shuri, M’Baku, Okoye and the Do...                en
# 7   Renegade bounty hunter Ryan Swan must carve hi...                en
# 8   A stockbroker in a small southern town gets em...                en
# 9   When Bússi, Iceland's toughest cop, is forced ...                is
# 10  On a mission to make Christmas unforgettable f...                en
# 11  When a master thief is sabotaged during a bank...                en
# 12  Having cleared his name, genius mechanic Lino ...                fr
# 13  Set in San Tiburon, the world's most dangerous...                en
# 14  After a teacher dies, his best friend — a form...                pl
# 15  After witnessing a bizarre, traumatic incident...                en
# 16  Disillusioned with life in the city, feeling o...                en
# 17  Deep inside the mountain of Dovre, something g...                no
# 18  Mykola is an eccentric pacifist who wants to b...                uk
# 19  When the Primm family moves to New York City, ...                en
#
#    release_date  popularity  vote_count  vote_average
# 0    2022-10-19    5735.977        2542           7.3
# 1    2022-09-15    3396.412         628           7.9
# 2    2022-11-15    2315.476         208           6.7
# 3    2022-11-01    1839.229          13           5.1
# 4    2022-10-26    1688.007           1           5.0
# 5    2022-09-02    1852.125          24           6.8
# 6    2022-11-09    1625.367        1227           7.5
# 7    2022-11-11    1535.697          40           6.2
# 8    2022-11-04    1586.703          22           5.1
# 9    2022-05-23    1178.238          34           6.4
# 10   2022-11-25    1161.330         627           7.5
# 11   2022-06-17    1180.899          21           6.0
# 12   2022-11-10    1123.192         150           6.6
# 13   2022-04-29    1064.864          36           5.3
# 14   2022-11-23    1640.159          39           5.8
# 15   2022-09-23    1000.489        1053           6.8
# 16   2022-11-16     993.636         498           7.2
# 17   2022-12-01    1542.387         389           6.9
# 18   2022-05-03     898.916         149           7.6
# 19   2022-10-07     946.248         147           7.9

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                     title  \
# 0                            Coach Carter
# 1                             I Am Legend
# 2           Barbie in 'A Christmas Carol'
# 3                               Ferdinand
# 4                               Gladiator
# 5                          The Aristocats
# 6                           Power Rangers
# 7                       Fear Street: 1994
# 8                   An Interview with God
# 9              Suicide Squad: Hell to Pay
# 10            Les Mystères de la duchesse
# 11  Eternal Sunshine of the Spotless Mind
# 12     Indiana Jones and the Last Crusade
# 13                The Curse of La Llorona
# 14                                 Broker
# 15           Spiral: From the Book of Saw
# 16              Secretary Rope Discipline
# 17                              Halloween
# 18        Chip and Potato: Chip's Holiday
# 19                           Emancipation
#
#                                              overview original_language  \
# 0   Based on a true story, in which Richmond High ...                en
# 1   Robert Neville is a scientist who was unable t...                en
# 2   On Christmas Eve, Kelly is reluctant to go to ...                en
# 3   Ferdinand, a little bull, prefers sitting quie...                en
# 4   In the year 180, the death of emperor Marcus A...                en
# 5   When Madame Adelaide Bonfamille leaves her for...                en
# 6   Saban's Power Rangers follows five ordinary te...                en
# 7   After a series of brutal slayings, a teen and ...                en
# 8   An up-and-coming journalist finds his world an...                en
# 9   Task Force X targets a powerful mystical objec...                en
# 10                                                                   fr
# 11  Joel Barish, heartbroken that his girlfriend u...                en
# 12  In 1938, an art collector appeals to eminent a...                en
# 13  A social worker dealing with the disappearance...                en
# 14  Boxes are left out for people to anonymously d...                ko
# 15  Working in the shadow of an esteemed police ve...                en
# 16  Secretary Sayo does some corporate snooping fo...                ja
# 17  Fifteen years after murdering his sister on Ha...                en
# 18  When falling coconuts keep everyone awake all ...                en
# 19  Inspired by the gripping true story of a man w...                en
#
#    release_date  popularity  vote_count  vote_average
# 0    2005-01-14      58.282        2306           7.5
# 1    2007-12-12      42.346       13818           7.2
# 2    2008-11-03      34.742         439           7.1
# 3    2017-12-09      39.948        2485           7.2
# 4    2000-05-04      45.039       15814           8.2
# 5    1970-12-24      37.734        4379           7.3
# 6    2017-03-23      44.486        3987           6.3
# 7    2021-06-28      42.660        1770           6.7
# 8    2018-08-20      40.983         213           7.0
# 9    2018-05-09      40.476         495           7.1
# 10   2022-09-11      38.267           3           6.3
# 11   2004-03-19      36.660       12819           8.1
# 12   1989-05-24      34.358        8489           7.8
# 13   2019-04-17      39.419        2039           5.7
# 14   2022-06-08      41.357         106           7.2
# 15   2021-05-12      42.934        1410           6.1
# 16   1981-05-29      36.760           2           1.5
# 17   1978-10-24      40.448        4566           7.6
# 18   2022-06-27      37.489           6           5.3
# 19   2022-12-02      44.905           1           9.0  >

# %%
# time to fetch all the 500 pages from the api
final=pd.DataFrame()
value=0
for j in range(50,70):
    response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(j)).json()
    popularity=[]
    vote_count=[]
    original_language=[]
    title=[]
    vote_average=[]
    overview=[]
    release_date=[]
    
    for i in response['results']:
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])
        title.append(i['title'])
        vote_average.append(i['vote_average'])
        
#   --------------------------------------------------------------------------    
        try:
            release_date.append(i['release_date'])
        except:
            release_date.append(np.nan)
                
                
#   ---------------------------------------------------------------------------              
        overview.append(i['overview'])
    
    d={'title':title,'overview':overview,'original_language':original_language,'release_date':release_date,'popularity':popularity,'vote_count':vote_count,'vote_average':vote_average}
    df=pd.DataFrame(d)
    final=final.append(df,ignore_index=True)
    final
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8552\3552362107.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df,ignore_index=True)

# %%
final
# Out:
#                                         title  \
# 0                Violet Evergarden: The Movie
# 1                                      Dakota
# 2                               The Ancestral
# 3                                        Dual
# 4                                         Elf
# ..                                        ...
# 395  Cirque du Freak: The Vampire's Assistant
# 396                                  Caligula
# 397                             Finding Grace
# 398                                   Sicario
# 399                                  I, Robot
#
#                                               overview original_language  \
# 0    As the world moves on from the war and technol...                ja
# 1    Dakota, an ex-service dog, joins single mum Ka...                en
# 2    After suffering a family tragedy, a widower na...                vi
# 3    A terminally ill woman opts for a cloning proc...                en
# 4    When young Buddy falls into Santa's gift sack ...                en
# ..                                                 ...               ...
# 395  Darren Shan is a regular teenage kid. He and h...                en
# 396  The perversion behind imperial Rome, the epic ...                en
# 397  A struggling family, already on the verge of d...                en
# 398  An idealistic FBI agent is enlisted by a gover...                en
# 399  In 2035, where robots are commonplace and abid...                en
#
#     release_date  popularity  vote_count  vote_average
# 0     2020-09-18      49.539         281           8.3
# 1     2022-04-01      56.395          13           6.2
# 2     2022-03-24      59.127          41           6.6
# 3     2022-03-18      38.495         170           6.1
# 4     2003-10-09      49.490        3367           6.6
# ..           ...         ...         ...           ...
# 395   2009-10-23      39.489         931           5.8
# 396   1979-08-14      39.466         606           6.0
# 397   2020-04-21      39.449          18           5.8
# 398   2015-09-17      39.445        7280           7.4
# 399   2004-07-15      39.436       10343           6.9
#
# [400 rows x 7 columns]

# %%
# genrate the csv_file
final.to_csv('Movies.csv')
