# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=sns.load_dataset('tips')

# %%
sns.relplot(data=tips)

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill' , y='tip', data=tips)
plt.show()

# %%
# the hue parameter
sns.relplot(x='total_bill' , y='tip',hue='smoker', data=data)
plt.show()
#  below it shows us the guy who given the tip is smoker or not

# %%
sns.relplot(x='total_bill' , y='tip',hue='smoker',style='sex', data=data)
plt.show()
# the style parameter differentiate between the male and female
#  below it shows us the guy who given the tip is smoker or not and the sex of the guy

# %%
sns.relplot(x='total_bill' , y='tip',hue='smoker',style='sex',size='size', data=data)
plt.show()
# continuos or numerical data in size

# %%
# scatterplot function
sns.scatterplot(x='total_bill' , y='tip',hue='smoker',style='sex',size='size', data=data)
plt.show()

# %%
# plotting on categorical data
# 1. catplot

# the first part of this is Categorical satterplot
# stripplot
# swarmplot
# 2.categorical distirbution plot
# boxplot
# voillinplot
# 3. categorical estimate plot
# pointplot
# Barplot
# countplot
# 4. categorical categorical plot
# hitmap
# custermaps
# plotting side by side graphs using facetGrids

# %% [markdown]
# # Categorical satterplot

# %%
sns.catplot(x='day' , y='tip',jitter=2, data=data)
plt.show()
# this is how script plot looks like
# jitter will reduce the noise

# %%
sns.swarmplot(x='day' , y='tip', data=data)
plt.show()

# %%
sns.swarmplot(x='day' , y='tip',hue='sex', data=data)
plt.show()

# %% [markdown]
# # box plot

# %%
sns.boxplot(data['tip'])
plt.show()
# Out:
# D:\Python\Anaconda\SetUp\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(data['total_bill'])
plt.show()
# Out:
# D:\Python\Anaconda\SetUp\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=data)
plt.show()

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=data)
plt.show()

# %%
sns.catplot(x='day',y='total_bill',hue='sex',kind='box',data=data)
plt.show()

# %% [markdown]
# # violin plot

# %%
sns.violinplot(data['total_bill'])
plt.show()
# Out:
# D:\Python\Anaconda\SetUp\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(x='day',y='total_bill',kind='violin',data=data)
plt.show()

# %%
sns.catplot(x='day',y='total_bill',kind='violin',hue='sex',split=True,data=data)
plt.show()

# %% [markdown]
# # bar plots and count plots

# %%
sns.catplot(x='smoker',y='total_bill',kind='bar',data=data)
plt.show()

# %%
sns.barplot(x='smoker',y='total_bill',hue='sex',data=data)
plt.show()

# %%
sns.barplot(x='smoker',y='total_bill',estimator=np.median,hue='sex',data=data)
plt.show()

# %%
# how to find out the count of male and female in our data
sns.catplot(x='sex',kind='count', hue='smoker',data=data)
plt.show()

# %% [markdown]
# # heatmap

# %%
flights=sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
x=flights.pivot_table(index='year',columns='month',values='passengers',aggfunc='sum')
x
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(x)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap(x)
plt.show()

# %%
# off the color bar
sns.heatmap(x,cbar=False)
plt.show()

# %%
sns.heatmap(x,cbar=False,linewidths=0.5)
plt.show()

# %%
sns.heatmap(x,cbar=False,linewidths=0.5,annot=True,fmt='d')
plt.show()

# %%
# change the colormap
sns.heatmap(x,cbar=False,linewidths=0.5,annot=True,fmt='d',cmap='viridis')
plt.show()

# %% [markdown]
# # clusterMap

# %%
sns.clustermap(x)
plt.show()

# %% [markdown]
# # joint plot

# %%
data=sns.load_dataset('tips')

# %%
sns.jointplot(x='total_bill',y='tip',data=data)
plt.show()
# plot the histogram on both the axis

# %%
sns.jointplot(x='total_bill',y='tip',kind='hex',data=data)
plt.show()
# this is hexplot
# this is 2d hexagram

# %%
# 2d kd plot

# %%
sns.jointplot(x='total_bill',y='tip',kind='kde',data=data)
plt.show()
# genrate the contour
# the smaller area are darker shade

# %%
# regression plot

# %%
sns.jointplot(x='total_bill',y='tip',kind='reg',data=data)
plt.show()

# %%
# pair plots

# %%
# used to plot multiple biveriates distribution in a data set

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')
plt.show()
# print the columns in both x and y axis

# %% [markdown]
# # distplots

# %%
# 3 things in one graph

# %%
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.distplot(titanic['age'])
plt.show()
# Out:
# D:\Python\Anaconda\SetUp\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# how can we only plot the histogram

# %%
sns.distplot(titanic['age'],kde=False)
plt.show()
# Out:
# D:\Python\Anaconda\SetUp\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# plotting only kde

# %%
sns.distplot(titanic['age'],hist=False)
plt.show()
# Out:
# D:\Python\Anaconda\SetUp\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# rugplot

# %%
sns.distplot(titanic['age'],hist=False,kde=False,rug=True)
plt.show()
# Out:
# D:\Python\Anaconda\SetUp\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Python\Anaconda\SetUp\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(titanic[titanic['survived']==1]['age'])
sns.distplot(titanic[titanic['survived']==0]['age'])
plt.show()
# Out:
# D:\Python\Anaconda\SetUp\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Python\Anaconda\SetUp\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
